# %% [markdown]
# # Module 4 - Introdução ao Pandas e carga de dados

# %% [markdown]
# ## 1\. Pacote pandas e os tipos de estruturas

# %% [markdown]
# ### Series e Index

# %%
import numpy as np
import pandas as pd
import requests

# %%
dados = [20900, 10450, 4180, 2090, 0]

# %%
indice = ['A', 'B', 'C', 'D', 'E']

# %%
s = pd.Series(data=dados, index=indice)
s
# Out:
# A    20900
# B    10450
# C     4180
# D     2090
# E        0
# dtype: int64

# %%
print(s['A'])
print(s['D'])
# Out:
# 20900
# 2090

# %%
s.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
s['A': 'C']
# Out:
# A    20900
# B    10450
# C     4180
# dtype: int64

# %% [markdown]
# ### Serie de um Dicionario

# %%
# serie a partir de um dicionário
class_dict = {
    'classe_A': 20900,
    'classe_B': 10450,
    'classe_C': 4180,
    'classe_D': 2090,
    'classe_E': 0,
}

serie_dict = pd.Series(class_dict)
serie_dict
# Out:
# classe_A    20900
# classe_B    10450
# classe_C     4180
# classe_D     2090
# classe_E        0
# dtype: int64

# %%
serie_dict.index
# Out:
# Index(['classe_A', 'classe_B', 'classe_C', 'classe_D', 'classe_E'], dtype='object')

# %%
# serie a partir de um nd array
pd.Series(np.random.randn(5))
# Out:
# 0   -0.032691
# 1    0.960660
# 2   -0.300080
# 3    1.569072
# 4   -0.493707
# dtype: float64

# %%
# serie a partir de um escalar
indice = [0, 1, 2, 3, 4]
pd.Series(5, index=indice)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %% [markdown]
# ## 2\. Dataframes

# %% [markdown]
# ### Dataframes de listas

# %%
# dataframe a partir de listas
pd.DataFrame([2,4,6,8,10], columns=['par'])
# Out:
#    par
# 0    2
# 1    4
# 2    6
# 3    8
# 4   10

# %% [markdown]
# ### Dataframes de dicionarios

# %%
# dataframe a partir de dicionario
pd.DataFrame({'impar': [1,3,5,7,9]})
# Out:
#    impar
# 0      1
# 1      3
# 2      5
# 3      7
# 4      9

# %%
df_dict = {
    'impar': [1,3,5,7,9],
    'par': [2,4,6,8,10]
}
pd.DataFrame(df_dict)
# Out:
#    impar  par
# 0      1    2
# 1      3    4
# 2      5    6
# 3      7    8
# 4      9   10

# %%
pop = {
    'São Paulo': 46649132,
    'Minas Gerais': 21411923,
    'Rio de Janeiro': 17463349,
    'Bahia': 14985284,
    'Paraná': 11597484,
    'Rio Grande do Sul': 11466630,
    'Pernambuco': 9674793,
}
pop_s = pd.Series(pop)
pop_s
# Out:
# São Paulo            46649132
# Minas Gerais         21411923
# Rio de Janeiro       17463349
# Bahia                14985284
# Paraná               11597484
# Rio Grande do Sul    11466630
# Pernambuco            9674793
# dtype: int64

# %%
area = {
    'São Paulo': 248219481,
    'Minas Gerais': 586521123,
    'Rio de Janeiro': 43750427,
    'Bahia': 564760427,
    'Paraná': 199298979,
    'Rio Grande do Sul': 281707156,
    'Pernambuco': 98067881,
}
area_s = pd.Series(area)
area_s
# Out:
# São Paulo            248219481
# Minas Gerais         586521123
# Rio de Janeiro        43750427
# Bahia                564760427
# Paraná               199298979
# Rio Grande do Sul    281707156
# Pernambuco            98067881
# dtype: int64

# %%
# dataframe a partir de duas series
df_brasil = pd.DataFrame({
    'População': pop_s,
    'Área': area_s
})
df_brasil
# Out:
#                    População       Área
# São Paulo           46649132  248219481
# Minas Gerais        21411923  586521123
# Rio de Janeiro      17463349   43750427
# Bahia               14985284  564760427
# Paraná              11597484  199298979
# Rio Grande do Sul   11466630  281707156
# Pernambuco           9674793   98067881

# %%
df_brasil['Área'].sum()
# Out:
# 2022325474

# %%
# criando uma nova coluna a partir de duas existentes
df_brasil['Densidade'] = df_brasil['População'] / df_brasil['Área']
df_brasil
# Out:
#                    População       Área  Densidade
# São Paulo           46649132  248219481   0.187935
# Minas Gerais        21411923  586521123   0.036507
# Rio de Janeiro      17463349   43750427   0.399158
# Bahia               14985284  564760427   0.026534
# Paraná              11597484  199298979   0.058191
# Rio Grande do Sul   11466630  281707156   0.040704
# Pernambuco           9674793   98067881   0.098654

# %%
df_brasil['Densidade']
# Out:
# São Paulo            0.187935
# Minas Gerais         0.036507
# Rio de Janeiro       0.399158
# Bahia                0.026534
# Paraná               0.058191
# Rio Grande do Sul    0.040704
# Pernambuco           0.098654
# Name: Densidade, dtype: float64

# %%
df_brasil.columns
# Out:
# Index(['População', 'Área', 'Densidade'], dtype='object')

# %%
df_brasil.dtypes
# Out:
# População      int64
# Área           int64
# Densidade    float64
# dtype: object

# %%
df_brasil.describe()
# Out:
#           População          Área  Densidade
# count  7.000000e+00  7.000000e+00   7.000000
# mean   1.903551e+07  2.889036e+08   0.121098
# std    1.282751e+07  2.124961e+08   0.134664
# min    9.674793e+06  4.375043e+07   0.026534
# 25%    1.153206e+07  1.486834e+08   0.038605
# 50%    1.498528e+07  2.482195e+08   0.058191
# 75%    1.943764e+07  4.232338e+08   0.143295
# max    4.664913e+07  5.865211e+08   0.399158

# %% [markdown]
# ## 3\. Objetos Index

# %% [markdown]
# ### Indexação Seleção e Filtragem

# %% [markdown]
# ```
# df[col] # resultado Series (seleciona uma coluna)
# df[[col1, col2]] # resultado Dataframe (seleciona duas colunas)
# df.loc[rotulo] # resultado Series (seleciona uma linha usando rótulo)
# df.iloc[i] # resultado Series (seleciona uma linha usando inteiro)
# df[2:5] # resultado Dataframe (recorta dataframe da linha 2 a 5)
# df[vetor_bool] # resultado Dataframe (seleciona uma linhas usando vetor boleano)
# ```

# %%
df_brasil['Área']
df_brasil.Área
# Out:
# São Paulo            248219481
# Minas Gerais         586521123
# Rio de Janeiro        43750427
# Bahia                564760427
# Paraná               199298979
# Rio Grande do Sul    281707156
# Pernambuco            98067881
# Name: Área, dtype: int64

# %%
# selecionando duas colunas no dataframe
df_brasil[['Área', 'População']]
# Out:
#                         Área  População
# São Paulo          248219481   46649132
# Minas Gerais       586521123   21411923
# Rio de Janeiro      43750427   17463349
# Bahia              564760427   14985284
# Paraná             199298979   11597484
# Rio Grande do Sul  281707156   11466630
# Pernambuco          98067881    9674793

# %%
# selecionando uma linha usando o nome
df_brasil.loc['Rio de Janeiro']
# Out:
# População    1.746335e+07
# Área         4.375043e+07
# Densidade    3.991584e-01
# Name: Rio de Janeiro, dtype: float64

# %%
# selecionando a linha pelo indice
df_brasil.iloc[3]
# Out:
# População    1.498528e+07
# Área         5.647604e+08
# Densidade    2.653388e-02
# Name: Bahia, dtype: float64

# %%
# recortando dataframe
df_brasil['Bahia': 'Rio Grande do Sul']
# Out:
#                    População       Área  Densidade
# Bahia               14985284  564760427   0.026534
# Paraná              11597484  199298979   0.058191
# Rio Grande do Sul   11466630  281707156   0.040704

# %%
bool_vector = df_brasil['Área'] > 290000000
bool_vector
# Out:
# São Paulo            False
# Minas Gerais          True
# Rio de Janeiro       False
# Bahia                 True
# Paraná               False
# Rio Grande do Sul    False
# Pernambuco           False
# Name: Área, dtype: bool

# %%
df_brasil[bool_vector]
# ou
df_brasil[df_brasil['Área'] > 290000000]
# Out:
#               População       Área  Densidade
# Minas Gerais   21411923  586521123   0.036507
# Bahia          14985284  564760427   0.026534

# %%
# traspondo o dataframe
df_brasil.T
# Out:
#               São Paulo  Minas Gerais  Rio de Janeiro         Bahia  \
# População  4.664913e+07  2.141192e+07    1.746335e+07  1.498528e+07
# Área       2.482195e+08  5.865211e+08    4.375043e+07  5.647604e+08
# Densidade  1.879350e-01  3.650665e-02    3.991584e-01  2.653388e-02
#
#                  Paraná  Rio Grande do Sul    Pernambuco
# População  1.159748e+07       1.146663e+07  9.674793e+06
# Área       1.992990e+08       2.817072e+08  9.806788e+07
# Densidade  5.819139e-02       4.070408e-02  9.865404e-02

# %%
# formatando para trazer no formato float com duas casas decimais
pd.options.display.float_format = '{:.2f}'.format

# %%
df_brasil
# Out:
#                    População       Área  Densidade
# São Paulo           46649132  248219481       0.19
# Minas Gerais        21411923  586521123       0.04
# Rio de Janeiro      17463349   43750427       0.40
# Bahia               14985284  564760427       0.03
# Paraná              11597484  199298979       0.06
# Rio Grande do Sul   11466630  281707156       0.04
# Pernambuco           9674793   98067881       0.10

# %%
# transforma o dataframe em um array
df_brasil.values
# Out:
# array([[4.66491320e+07, 2.48219481e+08, 1.87935015e-01],
#        [2.14119230e+07, 5.86521123e+08, 3.65066528e-02],
#        [1.74633490e+07, 4.37504270e+07, 3.99158367e-01],
#        [1.49852840e+07, 5.64760427e+08, 2.65338775e-02],
#        [1.15974840e+07, 1.99298979e+08, 5.81913869e-02],
#        [1.14666300e+07, 2.81707156e+08, 4.07040778e-02],
#        [9.67479300e+06, 9.80678810e+07, 9.86540435e-02]])

# %%
df_brasil.values[0]
# Out:
# array([4.66491320e+07, 2.48219481e+08, 1.87935015e-01])

# %%
# filtrando e trazendo apenas a coluna Densidade
df_brasil.loc[df_brasil['Densidade'] < 0.05, 'Densidade']
# Out:
# Minas Gerais        0.04
# Bahia               0.03
# Rio Grande do Sul   0.04
# Name: Densidade, dtype: float64

# %%
# alterando os valores retornados
df_test = df_brasil
df_test.loc[df_brasil['Densidade'] < 0.05, 'Densidade'] = 5000
df_test
# Out:
#                    População       Área  Densidade
# São Paulo           46649132  248219481       0.19
# Minas Gerais        21411923  586521123    5000.00
# Rio de Janeiro      17463349   43750427       0.40
# Bahia               14985284  564760427    5000.00
# Paraná              11597484  199298979       0.06
# Rio Grande do Sul   11466630  281707156    5000.00
# Pernambuco           9674793   98067881       0.10

# %%
# acessando via index
df_test.iloc[2 ,2] = 1000
df_test
# Out:
#                    População       Área  Densidade
# São Paulo           46649132  248219481       0.19
# Minas Gerais        21411923  586521123    5000.00
# Rio de Janeiro      17463349   43750427    1000.00
# Bahia               14985284  564760427    5000.00
# Paraná              11597484  199298979       0.06
# Rio Grande do Sul   11466630  281707156    5000.00
# Pernambuco           9674793   98067881       0.10

# %% [markdown]
# ## 4\. Operações entre DataFrames e Series

# %%
# gerando uma array randomica
r_array = np.random.randint(10, size=(3, 5))
r_array
# Out:
# array([[1, 0, 1, 1, 7],
#        [7, 7, 4, 6, 9],
#        [8, 7, 9, 3, 3]])

# %%
# gerando um dataframe a partir da array e renomeando colunas
r_array = np.random.randint(10, size=(3, 5))
df1 = pd.DataFrame(r_array, columns=['A','B','C','D','E'])
df1
# Out:
#    A  B  C  D  E
# 0  5  2  2  8  5
# 1  7  1  7  0  0
# 2  1  6  2  3  8

# %%
r_array = np.random.randint(10, size=(3, 5))
df2 = pd.DataFrame(r_array, columns=['A','B','C','D','E'])
df2
# Out:
#    A  B  C  D  E
# 0  7  8  6  1  9
# 1  0  6  7  4  8
# 2  1  9  3  9  0

# %%
# somando cada celula de cada dataframe
df1 + df2
# Out:
#     A   B   C   D   E
# 0  12  10   8   9  14
# 1   7   7  14   4   8
# 2   2  15   5  12   8

# %%
r_array = np.random.randint(10, size=(1, 5))
df3 = pd.DataFrame(r_array, columns=['A','B','C','D','E'])
df3
# Out:
#    A  B  C  D  E
# 0  2  6  7  6  2

# %%
df1 + df3
# Out:
#      A    B    C     D    E
# 0 7.00 8.00 9.00 14.00 7.00
# 1  NaN  NaN  NaN   NaN  NaN
# 2  NaN  NaN  NaN   NaN  NaN

# %%
df1.iloc[0]
# Out:
# A    5
# B    2
# C    2
# D    8
# E    5
# Name: 0, dtype: int64

# %%
df1 - df1.iloc[0]
# Out:
#    A  B  C  D  E
# 0  0  0  0  0  0
# 1  2 -1  5 -8 -5
# 2 -4  4  0 -5  3

# %%
df1.iloc[2] = 0
df1
# Out:
#    A  B  C  D  E
# 0  5  2  2  8  5
# 1  7  1  7  0  0
# 2  0  0  0  0  0

# %%
df1 * 100 + 200
# Out:
#      A    B    C     D    E
# 0  700  400  400  1000  700
# 1  900  300  900   200  200
# 2  200  200  200   200  200

# %%
df1.T
# Out:
#    0  1  2
# A  5  7  0
# B  2  1  0
# C  2  7  0
# D  8  0  0
# E  5  0  0

# %%
np.exp(df1)
# Out:
#         A    B       C       D      E
# 0  148.41 7.39    7.39 2980.96 148.41
# 1 1096.63 2.72 1096.63    1.00   1.00
# 2    1.00 1.00    1.00    1.00   1.00

# %% [markdown]
# ### Análise sobre dados de vacinação da Covid no Rio de Janeiro

# %%
# dados de vacinação RJ Parte 1
url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DRJ/part-00000-5d24afa3-5470-48ec-adea-cb8dbb7e9da9.c000.csv'
csv = '/content/drive/MyDrive/Colab Notebooks/EBAC Curso Ciência de Dados/Cientista de Dados/part-00000-5d24afa3-5470-48ec-adea-cb8dbb7e9da9.c000.csv'

# %%
df_covid = pd.read_csv(csv, sep=';')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-54-ebf2695d0196> in <module>()
# ----> 1 df_covid = pd.read_csv(csv, sep=';')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     222         try:
#     223             if self.low_memory:
# --> 224                 chunks = self._reader.read_low_memory(nrows)
#     225                 # destructive to chunks
#     226                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df_covid.head(5)
# df_covid.info()

# %%
df_covid_copy = df_covid[:20000].copy()

# %% [markdown]
# > Percentual de pessoas vacinadas na capital

# %%
df_covid_copy['paciente_endereco_nmMunicipio'] == 'RIO DE JANEIRO'

# %%
df_covid_copy['flag_capital'] = 0

# %%
df_covid_copy.head(1)

# %%
df_covid_copy.loc[df_covid_copy['paciente_endereco_nmMunicipio'] == 'RIO DE JANEIRO', 'flag_capital'] = 1

# %%
df_covid_copy[['paciente_endereco_nmMunicipio', 'flag_capital']]

# %%
df_covid_copy['flag_capital'].sum()

# %%
# porcentagem dos pacientes vacinados
percent = df_covid_copy['flag_capital'].sum() / len(df_covid_copy.index)
percent *= 100

print(f'Foram vacinadas {round(percent, 2)} % pessoas no Rio de Janeiro (referente a parte 1 do arquivo)')

# %%
# media da idade dos pacientes vacinados
df_covid_copy['paciente_idade'].mean()

# %%
df_covid_copy['paciente_idade'].describe()

# %% [markdown]
# ## 5\. Valores únicos, contadores e pertinência

# %% [markdown]
# ### Dados BNDS

# %%
csv_bnds = '/content/drive/MyDrive/Colab Notebooks/EBAC Curso Ciência de Dados/Cientista de Dados/aprovacoes-por-uf-aprovacoes.csv'

# %%
df_bnds = pd.read_csv(csv_bnds, sep=';', decimal=',')

# %%
df_bnds.head(5)

# %%
# valores unicos de uma coluna
df_bnds['ano'].unique()

# %%
# quantidade de valores distintos de uma coluna
df_bnds['ano'].nunique()

# %%
df_bnds['mes'].unique()

# %%
df_bnds['mes'].nunique()

# %%
# colunas unicas do arquivo
df_bnds.columns.unique()

# %%
#  colunas distintas a partir da coluna acre ou seja removendo ano e mes
df_bnds.loc[:,'acre':].columns.unique()

# %%
df_bnds.loc[:,'acre':].columns.nunique()

# %% [markdown]
# ## 6\. Arquivos texto e JSON

# %% [markdown]
# ### Datasets BNDESP

# %%
import pandas as pd

# %%
csv_file = 'https://dadosabertos.bndes.gov.br/dataset/68a85772-df73-4c8b-8b8c-398f494fcca8/resource/10ff2d60-02d1-4619-8e42-24fc2a5927dd/download/renda-variavel-participacoes-acionarias-historico-da-carteira.csv'

# %%
df_pa = pd.read_csv(csv_file, sep=';', encoding='utf8', decimal=',')

# %%
df_pa.head(3)

# %%
df_pa.info()
print('\n')
df_pa.dtypes

# %%
# quantidade de empresas por ano que o BNDESP teve participação
df_pa['ano'].value_counts()

# %%
# Quais empresas o BNDESP já teve participação
df_pa['sigla'].unique()

# %%
# Quais empresas o BNDESP tem participação em 2021
df_pa_2021 = df_pa[df_pa['ano'] == 2021]
df_pa_2021['sigla'].unique()

# %% [markdown]
# ### Lendo arquivo JSON

# %%
json_file = 'https://raw.githubusercontent.com/prust/wikipedia-movie-data/master/movies.json'

# %%
movies = pd.read_json(json_file)

# %%
movies.head(5)

# %%
movies.dtypes

# %%
movies.columns

# %%
# expandindo listas movies['genres'] é uma lista de generos
movies['genres'].explode()

# %%
# valores unicos da lista
movies['genres'].explode().unique()

# %%
# quantidade de filmes de cada genero
movies['genres'].explode().value_counts()

# %% [markdown]
# ## 7\. Interagindo com APIs da Web e Bancos de dados

# %%
import pandas as pd
import requests

url_pvl_rj = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

url_pvl_sp = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=SP&tipo_interessado=Estado'

# %%
result = requests.get(url_pvl_rj)

# %%
result.status_code

# %%
data_json = result.json()
df = pd.DataFrame(data_json['items'])

# %%
df
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 0        4997           Estado  Rio de Janeiro        33  RJ
# 1       10890           Estado  Rio de Janeiro        33  RJ
# 2        5918           Estado  Rio de Janeiro        33  RJ
# 3        6833           Estado  Rio de Janeiro        33  RJ
# 4       10002           Estado  Rio de Janeiro        33  RJ
# 5        7080           Estado  Rio de Janeiro        33  RJ
# 6        8556           Estado  Rio de Janeiro        33  RJ
# 7        9750           Estado  Rio de Janeiro        33  RJ
# 8        5645           Estado  Rio de Janeiro        33  RJ
# 9        7187           Estado  Rio de Janeiro        33  RJ
# 10       9050           Estado  Rio de Janeiro        33  RJ
# 11       6660           Estado  Rio de Janeiro        33  RJ
# 12       9102           Estado  Rio de Janeiro        33  RJ
# 13      21660           Estado  Rio de Janeiro        33  RJ
# 14       7255           Estado  Rio de Janeiro        33  RJ
# 15      13364           Estado  Rio de Janeiro        33  RJ
# 16      10562           Estado  Rio de Janeiro        33  RJ
# 17       5630           Estado  Rio de Janeiro        33  RJ
# 18       5635           Estado  Rio de Janeiro        33  RJ
# 19       5640           Estado  Rio de Janeiro        33  RJ
# 20      12375           Estado  Rio de Janeiro        33  RJ
# 21      13560           Estado  Rio de Janeiro        33  RJ
# 22       5516           Estado  Rio de Janeiro        33  RJ
# 23      21388           Estado  Rio de Janeiro        33  RJ
# 24      13624           Estado  Rio de Janeiro        33  RJ
# 25       7085           Estado  Rio de Janeiro        33  RJ
# 26      11306           Estado  Rio de Janeiro        33  RJ
# 27      10673           Estado  Rio de Janeiro        33  RJ
# 28      22594           Estado  Rio de Janeiro        33  RJ
# 29      10606           Estado  Rio de Janeiro        33  RJ
# 30      12410           Estado  Rio de Janeiro        33  RJ
# 31       9898           Estado  Rio de Janeiro        33  RJ
# 32      13483           Estado  Rio de Janeiro        33  RJ
# 33       5923           Estado  Rio de Janeiro        33  RJ
# 34      13629           Estado  Rio de Janeiro        33  RJ
# 35       7057           Estado  Rio de Janeiro        33  RJ
# 36       7084           Estado  Rio de Janeiro        33  RJ
# 37       8528           Estado  Rio de Janeiro        33  RJ
# 38      13271           Estado  Rio de Janeiro        33  RJ
# 39       5933           Estado  Rio de Janeiro        33  RJ
# 40       5952           Estado  Rio de Janeiro        33  RJ
# 41      11961           Estado  Rio de Janeiro        33  RJ
# 42      10849           Estado  Rio de Janeiro        33  RJ
# 43       9042           Estado  Rio de Janeiro        33  RJ
# 44      10561           Estado  Rio de Janeiro        33  RJ
# 45      13634           Estado  Rio de Janeiro        33  RJ
# 46       7150           Estado  Rio de Janeiro        33  RJ
# 47       5943           Estado  Rio de Janeiro        33  RJ
# 48      12018           Estado  Rio de Janeiro        33  RJ
# 49       7525           Estado  Rio de Janeiro        33  RJ
# 50       7129           Estado  Rio de Janeiro        33  RJ
# 51       7141           Estado  Rio de Janeiro        33  RJ
#
#                  num_pvl                                             status  \
# 0                   None                                           Deferido
# 1                   None  Encaminhado à PGFN com manifestação técnica fa...
# 2                   None  Encaminhado à PGFN com manifestação técnica fa...
# 3                   None                                           Deferido
# 4                   None  Encaminhado à PGFN com manifestação técnica fa...
# 5                   None  Encaminhado à PGFN com manifestação técnica fa...
# 6                   None  Encaminhado à PGFN com manifestação técnica fa...
# 7                   None                                           Deferido
# 8                   None  Encaminhado à PGFN com manifestação técnica fa...
# 9                   None  Encaminhado à PGFN com manifestação técnica fa...
# 10                  None  Encaminhado à PGFN com manifestação técnica fa...
# 11                  None                                           Deferido
# 12                  None  Encaminhado à PGFN com manifestação técnica fa...
# 13  00000.000000/2026-68                                 Arquivado a pedido
# 14                  None  Encaminhado à PGFN com manifestação técnica fa...
# 15                  None  Encaminhado à PGFN com manifestação técnica fa...
# 16                  None  Encaminhado à PGFN com manifestação técnica fa...
# 17                  None  Encaminhado à PGFN com manifestação técnica fa...
# 18                  None  Encaminhado à PGFN com manifestação técnica fa...
# 19                  None                                 Arquivado a pedido
# 20                  None  Encaminhado à PGFN com manifestação técnica fa...
# 21                  None                                           Deferido
# 22                  None  Encaminhado à PGFN com manifestação técnica fa...
# 23  00000.000000/2024-66  Encaminhado à PGFN com manifestação técnica fa...
# 38  Operação contratual externa (com garantia da U...
# 39  Operação contratual externa (com garantia da U...
# 40                        Operação contratual interna
# 41  Operação contratual interna (com garantia da U...
# 42  Operação contratual interna (com garantia da U...
# 43  Operação contratual interna (com garantia da U...
# 44  Operação contratual interna (com garantia da U...
# 45                        Operação contratual interna
# 46  Operação contratual externa (com garantia da U...
# 47  Operação contratual externa (com garantia da U...
# 48  Operação contratual externa (com garantia da U...
# 49                        Operação contratual interna
# 50  Operação contratual interna (com garantia da U...
# 51  Operação contratual interna (com garantia da U...
#
#                                            finalidade  \
# 0                                                PMAE
# 1                                          Proinveste
# 2                                      Infraestrutura
# 3                                      Multissetorial
# 4                                            Profisco
# 5                                      Multissetorial
# 6                                      Multissetorial
# 7                                      Infraestrutura
# 8                                      Infraestrutura
# 9                                      Infraestrutura
# 10                                     Infraestrutura
# 11                                      PAC - Favelas
# 12  PEF - Programa Emergencial de Financiamento do...
# 13                       Fortalecimento Institucional
# 14                                     Infraestrutura
# 15                                     Infraestrutura
# 16                                     Infraestrutura
# 17                       Fortalecimento Institucional
# 18                                     Infraestrutura
# 19                                     Infraestrutura
# 20                Preservação e recuperação ambiental
# 21                                     Infraestrutura
# 22                        Desenvolvimento sustentável
# 23                                     Infraestrutura
# 24                                     Infraestrutura
# 25                                     Infraestrutura
# 26                       Fortalecimento Institucional
# 27                                PAC - Copa Estádios
# 28                                     Infraestrutura
# 29     Aquisição de máquinas, equipamentos e veículos
# 30                                     Infraestrutura
# 31                                              Saúde
# 32                            Renegociação de dívidas
# 33                                     Infraestrutura
# 34     Aquisição de máquinas, equipamentos e veículos
# 35                                     Infraestrutura
# 36                       Fortalecimento Institucional
# 37  Aquisição de terrenos, imóveis e/ou construção...
# 38                              Desenvolvimento rural
# 39                                     Infraestrutura
# 40                                     Infraestrutura
# 41  PEF - Programa Emergencial de Financiamento do...
# 42                                     Multissetorial
# 43                                     Infraestrutura
# 44                                 PAC 2 - Saneamento
# 45     Aquisição de máquinas, equipamentos e veículos
# 46                              Desenvolvimento rural
# 47                                     Multissetorial
# 48                                     Infraestrutura
# 49                            PAC - Saneamento - 2008
# 50                                     Infraestrutura
# 51                        Desenvolvimento sustentável
#
#                              tipo_credor  \
# 0        Instituição Financeira Nacional
# 1        Instituição Financeira Nacional
# 2   Instituição Financeira Internacional
# 3        Instituição Financeira Nacional
# 4   Instituição Financeira Internacional
# 5   Instituição Financeira Internacional
# 6   Instituição Financeira Internacional
# 7        Instituição Financeira Nacional
# 8        Instituição Financeira Nacional
# 9   Instituição Financeira Internacional
# 10       Instituição Financeira Nacional
# 11       Instituição Financeira Nacional
# 12       Instituição Financeira Nacional
# 13       Instituição Financeira Nacional
# 14       Instituição Financeira Nacional
# 15  Instituição Financeira Internacional
# 16  Instituição Financeira Internacional
# 17  Instituição Financeira Internacional
# 18       Instituição Financeira Nacional
# 19  Instituição Financeira Internacional
# 20  Instituição Financeira Internacional
# 21       Instituição Financeira Nacional
# 22  Instituição Financeira Internacional
