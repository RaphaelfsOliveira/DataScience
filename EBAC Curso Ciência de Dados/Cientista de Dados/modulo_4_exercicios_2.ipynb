# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os tutores
# - Divirta-se :)
#
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])
df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])
df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])
df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])
df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])
df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])
df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
print(f'''
Percentual de acerto dos alunos por assunto:

Matemática: {round(df_mat['Qt_acertos'].sum() / 24, 2)}
Português: {round(df_por['Qt_acertos'].sum() / 18, 2)}
Geografia: {round(df_geo['Qt_acertos'].sum() / 8, 2)}
Inglês: {round(df_ing['Qt_acertos'].sum() / 8, 2)}
História: {round(df_his['Qt_acertos'].sum() / 8, 2)}
Física: {round(df_fis['Qt_acertos'].sum() / 12, 2)}
Química: {round(df_qui['Qt_acertos'].sum() / 12, 2)}
''')
# Out:
# Percentual de acerto dos alunos por assunto:
#
# Matemática: 49.38
# Português: 40.17
# Geografia: 42.0
# Inglês: 47.62
# História: 45.0
# Física: 44.33
# Química: 45.25

# %%
# 2) Seu código aqui 
df_total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
df_total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui 
total_questoes = 24 + 18 + 8 + 8 + 8 + 12 + 12
df_total['percent_acertos'] = round((df_total['Qt_acertos'] / total_questoes) * 100, 2)

df_total
# Out:
#     Qt_acertos  percent_acertos
# 0           35            38.89
# 1           48            53.33
# 2           50            55.56
# 3           32            35.56
# 4           30            33.33
# ..         ...              ...
# 95          34            37.78
# 96          27            30.00
# 97          40            44.44
# 98          40            44.44
# 99          42            46.67
#
# [100 rows x 2 columns]

# %%
# 4) Seu código aqui
df_total[df_total['Qt_acertos'] > 45].count()
# Out:
# Qt_acertos         31
# percent_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_dict = {
    'Matemática': df_mat['Qt_acertos'],
    'Português': df_por['Qt_acertos'],
    'Geografia': df_geo['Qt_acertos'],
    'Inglês': df_ing['Qt_acertos'],
    'História': df_his['Qt_acertos'],
    'Física': df_fis['Qt_acertos'],
    'Química': df_qui['Qt_acertos'],
}
df_geral = pd.DataFrame(df_dict)
df_geral.head(2)
# Out:
#    Matemática  Português  Geografia  Inglês  História  Física  Química
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8

# %%
df_desq = df_geral[(df_geral['Matemática'] == 0) | (df_geral['Física'] == 0) | (df_geral['Química'] == 0)]
df_desq.head(5)
# Out:
#     Matemática  Português  Geografia  Inglês  História  Física  Química
# 3           10          7          3       4         0       0        8
# 6            6          0          7       7         5       0        4
# 10          10          8          3       2         1       7        0
# 12          20          8          3       7         1       0        3
# 14           7         11          1       7         1       4        0

# %%
# Quantos são esses alunos?
len(df_desq.index)
# Out:
# 23

# %%
# Qual a média desses alunos em história e geografia?
print(f'''
Média em História: {round(df_desq['História'].sum() / 8, 2)}
Média em Geografia: {round(df_desq['Geografia'].sum() / 8, 2)}
''')
# Out:
# Média em História: 9.88
# Média em Geografia: 9.25

# %%
# Monte um DataFrame com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.
# df_qualif = df_geral.filter(items!=df_desq.index, axis=0)

df_qualif = df_geral.loc[set(df_geral.index) - set(df_desq.index)]

df_qualif[['Matemática', 'Física', 'Química']].describe()

df_qualif.head(5)
# Out:
# /var/folders/wh/_2xtz5kd2knd10y0m8tmqhrc0000gp/T/ipykernel_13504/481394905.py:4: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df_qualif = df_geral.loc[set(df_geral.index) - set(df_desq.index)]
#    Matemática  Português  Geografia  Inglês  História  Física  Química
# 0           6          7          7       3         1       8        3
# 1          19         10          0       0         0      11        8
# 2          14         16          0       5         7       4        4
# 4           7          2          2       7         0       9        3
# 5          20          2          5       3         2       9        9

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?

# %%
arquivo = './input/registros de vacinacao covid ACRE.csv'
df_vac_acre = pd.read_csv(arquivo, sep=';')

# %%
# 1) Sua solução aqui

fields = [
#     'vacina_categoria_codigo',
#     'vacina_categoria_nome',
#     'vacina_lote',
#     'vacina_fabricante_referencia',
    'vacina_codigo',
]
df_vac_acre.dtypes
# df_vac_acre[fields].count()
# Out:
# document_id                                  object
# paciente_id                                  object
# paciente_idade                                int64
# paciente_datanascimento                      object
# paciente_enumsexobiologico                   object
# paciente_racacor_codigo                       int64
# paciente_racacor_valor                       object
# paciente_endereco_coibgemunicipio           float64
# paciente_endereco_copais                    float64
# paciente_endereco_nmmunicipio                object
# paciente_endereco_nmpais                     object
# paciente_endereco_uf                         object
# paciente_endereco_cep                       float64
# paciente_nacionalidade_enumnacionalidade     object
# estabelecimento_valor                         int64
# estabelecimento_razaosocial                  object
# estalecimento_nofantasia                     object
# estabelecimento_municipio_codigo              int64
# ...

# %%
# 2) 
unique_values = df_vac_acre['paciente_id'].unique()
len(unique_values)
# Out:
# 120517

# %%
# 3) 
df_vac_acre.dtypes
df_vac_acre['vacina_descricao_dose'].value_counts()
# Out:
#     1ª Dose    120939
#     2ª Dose     48107
#     Dose           25
# Name: vacina_descricao_dose, dtype: int64

# %%
# 3) solução alternativa
df_vac_acre.isnull().sum()

df_drop_dup = df_vac_acre.drop_duplicates(subset=['paciente_id', 'vacina_descricao_dose'])
df_drop_dup['vacina_descricao_dose'].value_counts()
# Out:
#     1ª Dose    119713
#     2ª Dose     47826
#     Dose           25
# Name: vacina_descricao_dose, dtype: int64

# %%
# 4) 
df_drop_dup_idade = df_vac_acre.drop_duplicates(subset=['paciente_id'])

df_drop_dup_idade[df_drop_dup_idade['paciente_idade'] < 18]['paciente_id'].count()
# Out:
# 47

# %%
# 5)
estab = [
    'estabelecimento_razaosocial',
    'estalecimento_nofantasia',
    'estabelecimento_municipio_codigo',
    'estabelecimento_municipio_nome',
]
df_mun_estab = df_vac_acre[estab]

df_mun_estab.count() # 169071
df_drop_dup_mun_estab = df_mun_estab.drop_duplicates(subset=['estalecimento_nofantasia'])

df_drop_dup_mun_estab.count() # 42
# df_drop_dup_mun_estab.value_counts()
# Out:
# estabelecimento_razaosocial         103
# estalecimento_nofantasia            103
# estabelecimento_municipio_codigo    103
# estabelecimento_municipio_nome      103
# dtype: int64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1) 
fields = [
    'estabelecimento_valor',
    'estabelecimento_razaosocial', 
    'estalecimento_nofantasia',
    'estabelecimento_municipio_codigo',
    'estabelecimento_municipio_nome',
    'estabelecimento_uf',
    'vacina_categoria_nome',
    'vacina_codigo',
]


df_menor_idade = df_vac_acre[df_vac_acre['paciente_idade'] < 18]
df_menor_idade.dtypes

df_estab_menor_idade = df_menor_idade[fields]

df_qtd_vac = df_estab_menor_idade.groupby(['estalecimento_nofantasia']).count()

df_estab_menor_idade.set_index('estalecimento_nofantasia', inplace=True)

# %%
df_estab_qtd_vac = df_estab_menor_idade.merge(df_qtd_vac['estabelecimento_valor'], on='estalecimento_nofantasia', how='inner')
df_estab_qtd_vac.columns = [
    'estabelecimento_valor',
    'estabelecimento_razaosocial',
    'estabelecimento_municipio_codigo',
    'estabelecimento_municipio_nome',
    'estabelecimento_uf',
    'vacina_categoria_nome',
    'vacina_codigo',
    'qtd_vacinas',
]

df_estab_qtd_vac.head()
# Out:
#                                                     estabelecimento_valor  \
# estalecimento_nofantasia
# ESF JOAO ALVES DA SILVA                                           2001314
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
#
#                                                                estabelecimento_razaosocial  \
# estalecimento_nofantasia
# ESF JOAO ALVES DA SILVA                             PREFEITURA MUNICIPAL DE EPITACIOLANDIA
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...      PREFEITURA MUNICIPAL DE RIO BRANCO
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...      PREFEITURA MUNICIPAL DE RIO BRANCO
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...      PREFEITURA MUNICIPAL DE RIO BRANCO
# ...

# %%
# 2) 
df_estab_qtd_vac.columns
# Out:
# Index(['estabelecimento_valor', 'estabelecimento_razaosocial',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_categoria_nome', 'vacina_codigo',
#        'qtd_vacinas'],
#       dtype='object')

# %%
# 3) Nesse DataFrame faça uma contagem do campo vacina_categoria_nome.

df_estab_qtd_vac['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %%
# 4) a partir da lista de colunas, 
# escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.

fields2 = [
    'estabelecimento_valor', 
    'estabelecimento_razaosocial',
    'estabelecimento_municipio_codigo', 
    'estabelecimento_municipio_nome',
    'estabelecimento_uf'
]
df_estab_qtd_vac[fields2]
# Out:
#                                                     estabelecimento_valor  \
# estalecimento_nofantasia
# ESF JOAO ALVES DA SILVA                                           2001314
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AMB...                6917291
# SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL                  6159087
# SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL                  6159087
# SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL                  6159087
# CENTRO DE SAUDE DIAMANTINO MACEDO                                 2000040
# CENTRO DE SAUDE DIAMANTINO MACEDO                                 2000040
# CENTRO DE SAUDE DIAMANTINO MACEDO                                 2000040
# ...

# %%
# 5) usando o método .loc, selecione somente essas variáveis

df_estab_qtd_vac.iloc[1, 3]
# Out:
# 'RIO BRANCO'

# %%
# 6) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, 
# com os dados do estabelecimento

df_estab_qtd_vac.reset_index().drop_duplicates(subset=['estalecimento_nofantasia'])
# Out:
#                              estalecimento_nofantasia  estabelecimento_valor  \
# 0                             ESF JOAO ALVES DA SILVA                2001314
# 1   DEPARTAMENTO DE VIGILANCIA EPIDEMIOLOGICA E AM...                6917291
# 5    SECRETARIA MUNICIPAL DE SAUDE DE CRUZEIRO DO SUL                6159087
# 8                   CENTRO DE SAUDE DIAMANTINO MACEDO                2000040
# 11                  POLO BASE DE MARECHAL THAUMATURGO                7625855
# 20                                 POLO BASE DE FEIJO                6748759
# 26                          POLO BASE DE PORTO WALTER                6308740
# 28                      UBS VICENTE VARELA DE ALMEIDA                2001748
# 36                       POLO BASE DE CRUZEIRO DO SUL                6917682
# 37                          POLO BASE DE ASSIS BRASIL                6428940
# 40  UNIDADE ASSISTENCIAL A SAUDE INDIGENA DE TARAU...                6612385
# ...
