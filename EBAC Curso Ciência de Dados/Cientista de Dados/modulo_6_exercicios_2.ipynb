# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
# %matplotlib notebook

# %%
# df = pd.read_csv('./SINASC_2019.csv', sep=';')
df = pd.read_csv('./input/SINASC_2019.csv', sep=';')
# Out:
# /var/folders/wh/_2xtz5kd2knd10y0m8tmqhrc0000gp/T/ipykernel_10428/3165088887.py:2: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./input/SINASC_2019.csv', sep=';')

# %%
df.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR'],
#       dtype='object')

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
df[['IDADEMAE']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
df[['PESO']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
df_age_mother = df[df['IDADEMAE'].isna() == False]
# df['IDADEMAE'].isna().value_counts()
df_age_mother.isna()
df_age_mother.head()

sns.displot(
    data=df_age_mother,
    alpha=.25,
    x='IDADEMAE',
    bins=20,
    # element='step',
    # kde=True
)

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
df2 = df[df['PESO'].isna() == False]

sns.displot(
    data=df2,
    alpha=.25,
    x='PESO',
    bins=20,
    # element='step',
    kde=True
)
