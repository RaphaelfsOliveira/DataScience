# %% [markdown]
# # Exercícios

# %%
# %%writefile credito.csv
# id_vendedor,valor_emprestimos,quantidade_emprestimos,data
# 104271,448.0,1,20161208
# 21476,826.7,3,20161208
# 87440,313.6,3,20161208
# 15980,-8008.0,6,20161208
# 215906,2212.0,5,20161208
# 33696,2771.3,2,20161208
# 33893,2240.0,3,20161208
# 214946,-4151.0,18,20161208
# 123974,2021.95,2,20161208
# 225870,4039.0,2,20161208
# Out:
# Writing credito.csv

# %%
emprestimos = []

with open(file='./credito.csv', mode='r', encoding='utf8') as fp:
  fp.readline() # cabeçalho
  linha = fp.readline()

  while linha:
    linha_emprestimo = {}
    linha_elementos = linha.strip().split(sep=',')
    linha_emprestimo['id_vendedor'] = linha_elementos[0]
    linha_emprestimo['valor_emprestimos'] = linha_elementos[1]
    linha_emprestimo['quantidade_emprestimos'] = linha_elementos[2]
    linha_emprestimo['data'] = linha_elementos[3]
    emprestimos.append(linha_emprestimo)
    linha = fp.readline()

# %%
for emprestimo in emprestimos:
  print(emprestimo)
# Out:
# {'id_vendedor': '104271', 'valor_emprestimos': '448.0', 'quantidade_emprestimos': '1', 'data': '20161208'}
# {'id_vendedor': '21476', 'valor_emprestimos': '826.7', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '87440', 'valor_emprestimos': '313.6', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '15980', 'valor_emprestimos': '-8008.0', 'quantidade_emprestimos': '6', 'data': '20161208'}
# {'id_vendedor': '215906', 'valor_emprestimos': '2212.0', 'quantidade_emprestimos': '5', 'data': '20161208'}
# {'id_vendedor': '33696', 'valor_emprestimos': '2771.3', 'quantidade_emprestimos': '2', 'data': '20161208'}
# {'id_vendedor': '33893', 'valor_emprestimos': '2240.0', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '214946', 'valor_emprestimos': '-4151.0', 'quantidade_emprestimos': '18', 'data': '20161208'}
# {'id_vendedor': '123974', 'valor_emprestimos': '2021.95', 'quantidade_emprestimos': '2', 'data': '20161208'}
# {'id_vendedor': '225870', 'valor_emprestimos': '4039.0', 'quantidade_emprestimos': '2', 'data': '20161208'}

# %% [markdown]
# ## 1. Função map
# > Aplique a função map na lista de emprestimos para extrair os valores da chave
# valor_emprestimos na lista valor_emprestimos_lista . Faça também a conversão
# de str para float .

# %%
valor_emprestimos_lista = list(map(lambda value: float(value['valor_emprestimos']), emprestimos))
print(valor_emprestimos_lista)
# Out:
# [448.0, 826.7, 313.6, -8008.0, 2212.0, 2771.3, 2240.0, -4151.0, 2021.95, 4039.0]

# %% [markdown]
# ## 2. Função filter
# > Aplique a função filter na lista de valor_emprestimos_lista para filtrar apenas os valores
# maiores que zero (os valores negativas são erros na base de dados). Salve os valores na lista
# valor_emprestimos_lista_filtrada .

# %%
valor_emprestimos_lista_filtrada = list(filter(lambda value: value > 0, valor_emprestimos_lista))
print(valor_emprestimos_lista_filtrada)
# Out:
# [448.0, 826.7, 313.6, 2212.0, 2771.3, 2240.0, 2021.95, 4039.0]

# %% [markdown]
# ## 3.1. Função reduce para extrair a soma
# > Aplique a função reduce para somar os elementos da lista
# valor_emprestimos_lista_filtrada na variavel soma_valor_emprestimos.

# %%
from functools import reduce

soma_valor_empresticos = round(reduce(lambda x, y: x + y, valor_emprestimos_lista_filtrada), 2)
print(soma_valor_empresticos)
# Out:
# 14872.55

# %% [markdown]
# ## 3.2. Função reduce para extrair a media aritimética
# > Aplique a função reduce para extrair a média aritimética (mais informações aqui) dos elementos
# da lista valor_emprestimos_lista_filtrada na variavel
# media_valor_emprestimos.

# %%
from functools import reduce

total = len(valor_emprestimos_lista_filtrada)
media_valor_emprestimos = reduce(lambda x, y: x + y, valor_emprestimos_lista_filtrada) / total
print(media_valor_emprestimos)
# Out:
# 1859.0687500000001

# %% [markdown]
# ## 3.3. (Desafio) Função reduce para extrair o desvio padrão
# > Aplique a função reduce para extrair a média aritimética (mais informações aqui) dos elementos
# da lista valor_emprestimos_lista_filtrada na variavel
# desvio_padrao_valor_emprestimos.

# %%
from statistics import stdev
from math import sqrt

print(f'correto -> {stdev(valor_emprestimos_lista_filtrada)}')

medias = [media_valor_emprestimos] * total


def desvio_padrao(x, media):
  return ((x - media) ** 2)

desvio_padrao_valor_emprestimos = reduce(lambda x, y: x + y, map(desvio_padrao, valor_emprestimos_lista_filtrada, medias))
div_desvio_padrao = (total - 1)

desvio_padrao_valor_emprestimos = desvio_padrao_valor_emprestimos / div_desvio_padrao
print(desvio_padrao_valor_emprestimos ** 0.5)
# Out:
# correto -> 1271.997271149785
# 1271.9972711497849
