# %% [markdown]
# # Python: Módulos & Pacotes

# %% [markdown]
# ## 1\. Comando import / módulos / pacotes

# %%
import random

nums = [n for n in range(0, 100)]

choice = random.choice(nums)
print(choice)

variable = random.random()
print(variable)
# Out:
# 76
# 0.4092609373327455

# %%
import math

pow = math.pow(2, 3)
print(pow)

num = math.ceil(10.01237)
print(num)

print(math.pi)
# Out:
# 8.0
# 11
# 3.141592653589793

# %%
# boa prática
from time import time, sleep

print(time())
sleep(3)
# Out:
# 1642937281.6455522

# %%
from datetime import datetime as dt

print(dt.now())
print(dt.now().date())

today = dt.now()
print('\n')
print(f"{today.strftime('%A')}, {today.day} of {today.strftime('%B')}, {today.year}")
# Out:
# 2022-01-23 11:39:16.290246
# 2022-01-23
#
#
# Sunday, 23 of January, 2022

# %% [markdown]
#  ## 2\. Trabalhando com módulos

# %%
# %%writefile carros.csv
# id,valor_venda,valor_manutencao,portas,pessoas,porta_malas
# 1,vhigh,med,2,2,small
# 2,med,vhigh,2,2,small
# 3,low,vhigh,2,2,small
# 4,low,high,2,2,small
# 5,low,high,2,2,small
# 6,low,high,4,4,big
# 7,low,high,4,4,big
# 8,low,med,2,2,small
# 9,low,med,2,2,small
# 10,low,med,2,2,small
# 11,low,med,4,4,big
# 12,low,low,2,2,small
# 13,low,low,4,4,small
# 14,low,low,4,4,med
# Out:
# Writing carros.csv

# %%
from arquivo_csv import ArquivoCSV, ArquivoTexto

arquivo_csv = ArquivoCSV(arquivo='carros.csv')

numero_linha = 1
print(arquivo_csv.extrair_linha(numero_linha=numero_linha)) # id,valor_venda,valor_manutencao,portas,pessoas,porta_malas

print(arquivo_csv.colunas) # ['id', 'valor_venda', 'valor_manutencao', 'portas', 'pessoas', 'porta_malas']

numero_linha = 10
print(arquivo_csv.extrair_linha(numero_linha=numero_linha)) # 9,low,med,2,2,small

numero_linha = 10
numero_coluna = 2
print(arquivo_csv.extrair_coluna_da_linha(numero_linha=numero_linha, numero_coluna=numero_coluna)) # low
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2cf443ace1fa> in <module>()
# ----> 1 from arquivo_csv import ArquivoCSV, ArquivoTexto
#       2
#       3 arquivo_csv = ArquivoCSV(arquivo='carros.csv')
#       4
#       5 numero_linha = 1
#
# ModuleNotFoundError: No module named 'arquivo_csv'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 3\. Trabalhando com pacotes

# %%
# %%writefile carros.csv
# id,valor_venda,valor_manutencao,portas,pessoas,porta_malas
# 1,vhigh,med,2,2,small
# 2,med,vhigh,2,2,small
# 3,low,vhigh,2,2,small
# 4,low,high,2,2,small
# 5,low,high,2,2,small
# 6,low,high,4,4,big
# 7,low,high,4,4,big
# 8,low,med,2,2,small
# 9,low,med,2,2,small
# 10,low,med,2,2,small
# 11,low,med,4,4,big
# 12,low,low,2,2,small
# 13,low,low,4,4,small
# 14,low,low,4,4,med
# Out:
# Writing carros.csv

# %%
from arquivo.file_csv import ArquivoCSV
from arquivo.file_txt import ArquivoTexto

# %%
file_car = ArquivoCSV('carros.csv')
line = file_car.extrair_linha(1)
line3 = file_car.extrair_linha(3)
print(line)
print(line3)
print(file_car.colunas)
# Out:
# id,valor_venda,valor_manutencao,portas,pessoas,porta_malas
#
# 2,med,vhigh,2,2,small
#
# ['id', 'valor_venda', 'valor_manutencao', 'portas', 'pessoas', 'porta_malas']

# %% [markdown]
# ## 4\. Baixando pacotes da web

# %%
pip install requests # faz download do gerenciador de pacotes pip, próprio do python

# %%
pip freeze # lista pacotes que estão instalados no ambiente
pip freeze > requirements.py # salva todos os pacotes com as versões dentro desse arquivo
pip install -r requirements.py # instala todos o pacotes que estão dentro do arquivo requirements.py

# %%
import requests

url = 'https://www2.cetip.com.br/ConsultarTaxaDi/ConsultarTaxaDICetip.aspx'

response = requests.get(url)

if response.status_code == 200:
  data = response.json()
  print(data)
else:
  print(reponse.text)
# Out:
# {'taxa': '9,15', 'dataTaxa': '21/01/2022', 'indice': '33.883,61', 'dataIndice': '24/01/2022'}

# %%
tax = data.get('taxa')

if tax:
  cdi = float(tax.replace(',', '.'))

print(cdi, type(cdi))
# Out:
# 9.15 <class 'float'>
